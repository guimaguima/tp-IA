# %%
import pandas as pd

# %%
df = pd.read_csv("data/registro_partida.csv")
df.groupby(['ModeloA', 'ModeloB','Profundidade']).mean()
# Out:
#                                                       Estados Visitados  \
# ModeloA             ModeloB             Profundidade
# Alpha-Beta          Iterative Deepening 2                     28.875000
#                                         3                    165.333333
#                                         4                    280.000000
#                                         5                   2847.562500
#                     MinMax              2                     28.875000
#                                         3                    165.333333
#                                         4                    280.000000
#                                         5                   2847.562500
# Iterative Deepening Alpha-Beta          2                     36.428571
#                                         3                    204.200000
#                                         4                    387.842105
# ...

# %%
df = pd.read_csv("data/registro_partida_1.csv")
df.groupby(['ModeloA', 'ModeloB','Profundidade']).mean()
# Out:
#                                                       Estados Visitados  \
# ModeloA             ModeloB             Profundidade
# Alpha-Beta          Iterative Deepening 2                     28.875000
#                                         3                    165.333333
#                                         4                    280.000000
#                                         5                   2847.562500
# Iterative Deepening Alpha-Beta          2                     36.428571
#                                         3                    204.200000
#                                         4                    387.842105
#                                         5                   3423.750000
#
#                                                       Tempo por Jogada
# ModeloA             ModeloB             Profundidade
# Alpha-Beta          Iterative Deepening 2                     0.000549
#                                         3                     0.002878
# ...
